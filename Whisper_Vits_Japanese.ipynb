# %% [markdown]
# ##### 点击上方菜单栏的“代码执行程序”，在“更改运行时类型”中选择硬件加速器为GPU
# ##### 避免Colab断开连接：按Ctrl+Shift+I等待弹窗然后点击控制台，输入以下内容并回车：
#
#
# ```
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()}
# setInterval(ConnectButton,60000);
# ```

# %% [markdown]
# ### Download Whisper

# %%
# !git clone https://github.com/AlexandaJerry/whisper-vits-japanese
# Out:
# Cloning into 'whisper-vits-japanese'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 148 (delta 13), reused 23 (delta 7), pack-reused 108
# Receiving objects: 100% (148/148), 43.81 MiB | 19.90 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %%capture
# !pip install git+https://github.com/openai/whisper.git

# %%
# !cp -r /content/whisper-vits-japanese/whisper/transcribe.py /usr/local/lib/python3.8/dist-packages/whisper
# !cp -r /content/whisper-vits-japanese/whisper/utils.py /usr/local/lib/python3.8/dist-packages/whisper

# %%
import whisper

# %% [markdown]
# ### Prepare Data for Whisper ASR

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###此处是唯一需要自己改动的地方：自己的音频zip路径

# %%
#目前支持日语，换成别语言需替换text文件夹cleaner和symbols以及config文件夹中isla_base.json的cleaner参数
#这里只需用新路径替换掉/content/drive/MyDrive/isla_base/isla.zip即可(音频需为wav)
#注意"*/*.wav"适用于压缩包内有子文件夹,然后子文件夹内存放着wav
#如果压缩包内直接就是音频wav,那么需要把"*/*.wav"替换为"/*.wav"

#!unzip -j /content/drive/MyDrive/isla_base/isla.zip "*/*.wav" -d /content/whisper-vits-japanese/audio

# %%
#如果没有训练数据只想体验的话，这里只能暂时借用下White老师的数据集了，作为入门材料真是万分感谢
# %cd /content/whisper-vits-japanese
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1H6aqdGP-h-MT7XAVk870Ql4d3QrJT-7o' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1H6aqdGP-h-MT7XAVk870Ql4d3QrJT-7o" -O "isla.zip" && rm -rf /tmp/cookies.txt
# !unzip -j /content/whisper-vits-japanese/isla.zip "*/*.wav" -d /content/whisper-vits-japanese/audio

# %%
#识别过程总共花费50分钟(大概是音频总长的三分之一到一半左右)
# !whisper -i /content/whisper-vits-japanese/audio -o /content/whisper-vits-japanese/srt_files --language Japanese
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:08<00:00, 54.6MiB/s]
# [00:00.000 --> 00:04.220] 他にはどういうポーズすればいい
# [00:00.000 --> 00:03.200] すごく神経質な人に見えた
# [00:00.000 --> 00:04.940] マーシャならつこさに、ソータに会ってほしいって思うはず。
# [00:04.940 --> 00:28.300] 自分の代わりに成長を見守ってほしいって。
# [00:00.000 --> 00:03.600] 私の寿命のこと、ごめんなさい
# [00:00.000 --> 00:03.000] ん?何か問題があるの?
# [00:00.000 --> 00:05.000] 私がつかさの誕生日を祝ってあげられるのは、今年だけなので
# [00:00.000 --> 00:03.000] つかさ、私を捕まえてみて
# [00:00.000 --> 00:02.460] その道具、便利だね
# [00:00.000 --> 00:02.820] 花火の時間まで、屋台みたい
# [00:00.000 --> 00:08.800] なんだか不思議。あの時は、まさか津かさとこうして観覧車に乗ってるなんて、想像もしてなかったので。
# [00:00.000 --> 00:03.600] この前、ウォーリスが夢中になっていたゲームだよね
# [00:00.000 --> 00:02.760] つかそのために、頑張った
# [00:00.000 --> 00:05.540] 水槽って、こんなにあるんだ。魚もいっぱい
# [00:00.000 --> 00:04.800] エルの、くいぐい来るところが、苦手なので…
# [00:00.000 --> 00:07.280] どうかお願い、私のこと忘れないで、覚えていてね。
# [00:00.000 --> 00:06.000] 辛いのに、泣くのを我慢して、頑張って笑おうとするところ。
# [00:00.000 --> 00:03.000] お茶を振る舞って、心を開いてもらう
# [00:00.000 --> 00:02.000] それは ちょっと…
# [00:00.000 --> 00:05.000] つかさが喜んでくれたら、私も嬉しいので
# [00:00.000 --> 00:04.000] ん?どうしたの?頭慣れて欲しい?
# [00:00.000 --> 00:03.260] おとぎ話の世界に来ちゃったみたいだね
# [00:00.000 --> 00:08.780] この境界、しばらくは誰も使う予定がないから、止まっていっても構わないって、宿泊用の小部屋もあるみたい。
# [00:00.000 --> 00:04.240] もらったこと許してくれる
# [00:00.000 --> 00:04.000] 出発する前に、二人だけで話があるの
# [00:00.000 --> 00:03.000] うん、そういうこと…
# [00:00.000 --> 00:08.000] 自分で触ってもなんでもないけど、誰かに触られたりするとくすぐったくなるよね。
# [00:00.000 --> 00:03.000] あっ、つかさ、おかえり。
# [00:00.000 --> 00:05.520] お金も所有者に出してもらうことが多いはず
# [00:00.000 --> 00:04.000] つかさ どうかした
# [00:00.000 --> 00:02.000] こんなにたくさんあるんだね
# [00:00.000 --> 00:04.240] ちゃんとしてる時もあるけど、油断してるといつもこう
# [00:00.000 --> 00:03.500] ね、つかさはあれ、やったことある?
# [00:00.000 --> 00:02.000] せめてアンディのプジを祈ろう
# [00:00.000 --> 00:03.800] 映画を見るときは、ポップコーンを食べるものなの?
# [00:00.000 --> 00:03.420] で、つかさ、そんなに見つめないで
# [00:00.000 --> 00:02.480] 作り方、レンに教わったので
# [00:00.000 --> 00:08.600] その間にカップにお湯を入れて温める そうすればお茶が冷めにくくなるから
# [00:00.000 --> 00:04.760] つかさが運転席に座ってるのって、なんだか新鮮
# [00:00.000 --> 00:04.000] つかさのお母さんとお父さん、素敵な人だった
# [00:00.000 --> 00:02.000] そうだよね
# [00:00.000 --> 00:05.000] 珍しい鳥が集まってくるから、バードウォッチング好きにはよく知られてるんだ
# [00:00.000 --> 00:04.000] ハーブの説明続けるね
# [00:00.000 --> 00:03.600] 私、教師みたいって言われたのは初めて
# [00:00.000 --> 00:02.660] そっか、課長に言われたんだ
# [00:00.000 --> 00:02.820] じゃあ、そういうことにしておくので
# [00:00.000 --> 00:04.520] 会社に行く時に二人分のお弁当を作って持っていきたいので
# [00:00.000 --> 00:03.420] かずきは、どうせ覚えてないので
# [00:00.000 --> 00:03.300] ぶっ、別に、通民無いので
# [00:00.000 --> 00:05.000] あとは、みんなの体調とか様子を見て、何を入れるか決める
# [00:00.000 --> 00:05.500] かずきは真面目だから、仕事って聞くとちゃんとしようって思うみたい。
# [00:00.000 --> 00:02.500] こんな感じで大丈夫そう?
# [00:00.000 --> 00:05.800] 前にもらったの。回収の仕事のときに、もう使わないからって。
# [00:00.000 --> 00:04.380] たぶん、アレキサンダーのツボみたいなものに入ったんだと思う
# [00:00.000 --> 00:03.000] 私、様子を見てこようかな
# [00:00.000 --> 00:08.360] 最初の全部署が利用しているので、多分ここだけで四五十人は暮らしている
# [00:00.000 --> 00:04.000] いいよ。でも、どこに?
# [00:00.000 --> 00:05.640] うん!すごくワクワクして楽しい!あと、食べ物も美味しい!
# [00:00.000 --> 00:04.240] それは何の仕事
# [00:00.000 --> 00:02.000] 仲がいい家族なんですね
# [00:00.000 --> 00:04.220] そんなたくさんの警備ロボットだ、戦ったの?
# [00:00.000 --> 00:02.660] つかさの横だから、ふんしん
# [00:00.000 --> 00:05.000] 私、すかさと恋人になれてよかった。
# [00:00.000 --> 00:04.000] でもその分、人間よりも無茶をしちゃうことがある。
# [00:00.000 --> 00:05.340] 迷惑かもしれないけど、つかさも、あんまり攻めないであげてね
# [00:00.000 --> 00:04.700] うん、上出来、日頃の積み重ねの成果だね
# [00:00.000 --> 00:05.500] でも、道路は私たちのこと、すごく親密に考えてくれてる。
# [00:00.000 --> 00:06.000] 私、あんまりカズキの役には立たなかったので
# [00:00.000 --> 00:02.760] つかさが一緒にいるだけで心強いよ
# [00:00.000 --> 00:03.000] すごい!一発必須だね!
# [00:00.000 --> 00:07.000] それなのに、私にありがとうって言ってくれる人が結構いて、不思議だったんだけど。
# [00:00.000 --> 00:02.000] 腕、つらくない
# [00:00.000 --> 00:03.600] 楽しかったけど、苦しかった。
# [00:00.000 --> 00:03.360] 新しいメガネは、つかさぎ選んでほしい
# [00:00.000 --> 00:06.160] つかさにも、何年かしたら、新しい恋人ができてるかもしれないね。
# [00:00.000 --> 00:07.840] やすたか、あんまりチャランポラんなことして、シェリーを困らせちゃダメだよ。優しくしてあげてね。
# [00:00.000 --> 00:05.200] お、落ち着いて…落ち着いてやればできる…
# [00:00.000 --> 00:04.780] あの時はキッチンで火が上がって消火装置が作動しちゃったよね
# [00:00.000 --> 00:02.800] もう少し歩いたら休憩しようね
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 599, in _main_loop
#     logit_filter.apply(logits, tokens)
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 436, in apply
#     if timestamp_logprob > max_text_token_logprob:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/whisper", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.7/dist-packages/whisper/transcribe.py", line 283, in cli
#     result = transcribe(model, audio_path, temperature=temperature, **args)
#   File "/usr/local/lib/python3.7/dist-packages/whisper/transcribe.py", line 162, in transcribe
#     result = decode_with_fallback(segment)[0]
#   File "/usr/local/lib/python3.7/dist-packages/whisper/transcribe.py", line 100, in decode_with_fallback
#     results = model.decode(segment, options)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 701, in decode
#     result = DecodingTask(model, options).run(mel)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 633, in run
#     tokens, sum_logprobs, no_speech_probs = self._main_loop(audio_features, tokens)
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 607, in _main_loop
#     self.inference.cleanup_caching()
#   File "/usr/local/lib/python3.7/dist-packages/whisper/decoding.py", line 149, in cleanup_caching
#     hook.remove()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py", line 23, in remove
#     del hooks_dict[self.id]
# KeyboardInterrupt

# %%
#auto.py会根据Whisper导出的srt自动切片音频、转写文本、转采样率为22050HZ
#最后会把适配VIST的数据格式汇总在/content/whisper-vits-japanese/filelists
#然后音频数据会被放在/content/whisper-vits-japanese/sliced_audio文件夹里
# !pip install pydub
# %cd /content/whisper-vits-japanese
# !python auto.py

# %% [markdown]
# ### Install Requirements of VITS

# %%
# !pip install -r requirements.txt
# !sudo apt-get install espeak -y

# %% [markdown]
# ### Alignment and Text Conversion

# %%
import os
path = "/content/whisper-vits-japanese"
os.chdir(path)
print(os.getcwd())
# Out:
# /content/whisper-vits-japanese

# %%
# %cd monotonic_align
# !python setup.py build_ext --inplace
# %cd ..

# %%
import os
path = "/content/whisper-vits-japanese"
os.chdir(path)
print(os.getcwd())
# Out:
# /content/whisper-vits-japanese

# %%
#如果输出提示nophoneme这种情况，检查下/content/whisper-vits-japanese/filelists的两个txt文件里有没有出现英文转写
# !python preprocess.py --text_index 1 --text_cleaners japanese_cleaners --filelists /content/whisper-vits-japanese/filelists/train_filelist.txt /content/whisper-vits-japanese/filelists/val_filelist.txt
# Out:
# START: /content/whisper-vits-japanese/filelists/train_filelist.txt
# Downloading: "https://github.com/r9y9/open_jtalk/releases/download/v1.11.1/open_jtalk_dic_utf_8-1.11.tar.gz"
# dic.tar.gz: 100% 22.6M/22.6M [00:02<00:00, 10.9MB/s]
# Extracting tar file /usr/local/lib/python3.7/dist-packages/pyopenjtalk/dic.tar.gz
# START: /content/whisper-vits-japanese/filelists/val_filelist.txt

# %% [markdown]
# ### Train

# %%
# !python train.py -c configs/isla_base.json -m isla_base

# %% [markdown]
# ### Inference

# %%
#如果出现大批量的log日志显示在输出的话
#在"代码执行程序"下拉菜单选择"重新启动代码程序"
#再从该代码框开始，重新运行进行推断和输出语音
import os
path = "/content/whisper-vits-japanese"
os.chdir(path)
print(os.getcwd())

# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm
# Out:
# /content/whisper-vits-japanese

# %%
hps = utils.get_hparams_from_file("/content/whisper-vits-japanese/configs/isla_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cuda()
_ = net_g.eval()

#下面的这个isla_base/G_6000.pth需要换成目标文件夹里数字最大的G_????.pth
_ = utils.load_checkpoint("/content/whisper-vits-japanese/logs/isla_base/G_19000.pth", net_g, None)

# %%
stn_tst = get_text("ビエザイゼリ,ーファーディエン", hps) #别在这里发癫 停顿可用…
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
stn_tst = get_text("ジウザイジョーァリ,ーファーディエン", hps) #就在这里发癫 停顿可用…
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Save Materials and Checkpoints to Drive for Future Usage

# %%
#把checkpoint存入google drive(这里用了RT防止递归式复制到目标文件夹)
# !cp -RT /content/whisper-vits-japanese/logs/ /content/drive/MyDrive/logs/
#把音频文件和对应抄本存入google drive
# !cp -RT /content/whisper-vits-japanese/sliced_audio/ /content/drive/MyDrive/sliced_audio/
# !cp -RT /content/whisper-vits-japanese/filelists/ /content/drive/MyDrive/filelists/

# %% [markdown]
#   保存好后需要做的检查：
# 1. 确认下Drive没有爆内存(免费用户的存储上限为15G)
# 2. 检查sliced_audio文件夹下的spec.pt可被双击打开

# %% [markdown]
# ![微信图片_20221022233548.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![微信图片_20221022233345.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Restart from Lastest Checkpoint in the Next Time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexandaJerry/whisper-vits-japanese
# Out:
# Cloning into 'whisper-vits-japanese'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 148 (delta 13), reused 23 (delta 7), pack-reused 108
# Receiving objects: 100% (148/148), 43.81 MiB | 36.39 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
#把google drive的checkpoint恢复到文件夹
# !cp -RT /content/drive/MyDrive/logs/ /content/whisper-vits-japanese/logs/
#把音频文件和对应抄本恢复到文件夹
# !cp -RT /content/drive/MyDrive/sliced_audio/ /content/whisper-vits-japanese/sliced_audio/
# !cp -RT /content/drive/MyDrive/filelists/ /content/whisper-vits-japanese/filelists/

# %%
# %cd /content/whisper-vits-japanese
# !pip install -r requirements.txt
# !sudo apt-get install espeak -y
# %cd monotonic_align
# !python setup.py build_ext --inplace
# %cd ..

# %%
# !python train.py -c configs/isla_base.json -m isla_base
# Out:
# [INFO] {'train': {'log_interval': 200, 'eval_interval': 1000, 'seed': 1234, 'epochs': 400, 'learning_rate': 0.0002, 'betas': [0.8, 0.99], 'eps': 1e-09, 'batch_size': 24, 'fp16_run': True, 'lr_decay': 0.999875, 'segment_size': 8192, 'init_lr_ratio': 1, 'warmup_epochs': 0, 'c_mel': 45, 'c_kl': 1.0}, 'data': {'training_files': 'filelists/train_filelist.txt.cleaned', 'validation_files': 'filelists/val_filelist.txt.cleaned', 'text_cleaners': ['japanese_cleaners'], 'max_wav_value': 32768.0, 'sampling_rate': 22050, 'filter_length': 1024, 'hop_length': 256, 'win_length': 1024, 'n_mel_channels': 80, 'mel_fmin': 0.0, 'mel_fmax': None, 'add_blank': True, 'n_speakers': 0, 'cleaned_text': True}, 'model': {'inter_channels': 192, 'hidden_channels': 192, 'filter_channels': 768, 'n_heads': 2, 'n_layers': 6, 'kernel_size': 3, 'p_dropout': 0.1, 'resblock': '1', 'resblock_kernel_sizes': [3, 7, 11], 'resblock_dilation_sizes': [[1, 3, 5], [1, 3, 5], [1, 3, 5]], 'upsample_rates': [8, 8, 2, 2], 'upsample_initial_channel': 512, 'upsample_kernel_sizes': [16, 16, 4, 4], 'n_layers_q': 3, 'use_spectral_norm': False}, 'model_dir': './logs/isla_base'}
# [WARNING] git hash values are different. fa3d6213(saved) != 69ecb6d9(current)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ./logs/isla_base/G_19000.pth
# [INFO] Loaded checkpoint './logs/isla_base/G_19000.pth' (iteration 214)
# ./logs/isla_base/D_19000.pth
# [INFO] Loaded checkpoint './logs/isla_base/D_19000.pth' (iteration 214)
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:607: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:800.)
#   normalized, onesided, return_complex)
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:607: UserWarning: ComplexHalf support is experimental and many operators don't support it yet. (Triggered internally at  ../aten/src/ATen/EmptyTensor.cpp:31.)
#   normalized, onesided, return_complex)
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py:175: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [1, 9, 96], strides() = [21984, 96, 1]
# bucket_view.sizes() = [1, 9, 96], strides() = [864, 96, 1] (Triggered internally at  ../torch/csrc/distributed/c10d/reducer.cpp:312.)
#   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
# [INFO] Train Epoch: 214 [48%]
# [INFO] [2.4694342613220215, 2.388223886489868, 5.171596527099609, 21.997522354125977, 1.5507731437683105, 1.2682931423187256, 19000, 0.00019462325483015215]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [INFO] Saving model and optimizer state at iteration 214 to ./logs/isla_base/G_19000.pth
# [INFO] Saving model and optimizer state at iteration 214 to ./logs/isla_base/D_19000.pth
# [INFO] ====> Epoch: 214
# Traceback (most recent call last):
